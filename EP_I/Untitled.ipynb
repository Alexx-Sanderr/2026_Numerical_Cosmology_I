# %%
import scipy as sp
import numpy as np
import matplotlib . pyplot as plt

from scipy . integrate import cumulative_trapezoid

# %%
def Hz (z , Omega_k , Omega_m , Omega_r , Omega_DE , w ):
    
    Hz = c /( H0 * np . sqrt ( Omega_k *(1 + z ) **2 + Omega_m *(1 + z ) **3 + Omega_r *(1 + z ) **4 + Omega_DE *(1+ z ) **(3*( w +1) ) ) )
    return Hz

# %%
def distances(H_z, z):

    
    for (i, H_z, z) in zip(H_z, z)
    
        D_z = cumulative_trapezoid ( Hz_values , z , initial = 0) # Calculate Comoving Radial distance D ( z )

    solutions_rad [ case_name ] = D_z
    
    D_A = D_z / (1 + z ) # Calculate angular diameter  distance D_A ( z )
    solutions_ang_diam [ case_name ] = D_A
    
    D_L = D_z * (1 + z ) # Calculate luminosity distance D_L ( z )

    return D_L, D_A, D_H
